# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GlobalAveragePooling1D, Dense

# Load GloVe embeddings (e.g., glove.6B.50d.txt)
embeddings_index = {}
with open("Datasets\glove.6B.50d\glove.6B.50d.txt", encoding="utf8") as f:
    for line in f:
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = vector

# Build embedding matrix for your vocabulary
vocab = ["i", "love", "deep", "learning", "nlp", "fun"]
embedding_dim = 50
embedding_matrix = np.zeros((len(vocab), embedding_dim))
for i, word in enumerate(vocab):
    vector = embeddings_index.get(word)
    if vector is not None:
        embedding_matrix[i] = vector

# Keras model
# Create a Sequential model where layers run in order
model = Sequential([

    # Embedding layer that converts word indices into dense vectors
    Embedding(
        # Total number of unique words in your vocabulary
        input_dim=vocab_size,

        # Size of each embedding vector (e.g., 50‑dim GloVe)
        output_dim=50,

        # Load pretrained GloVe embedding matrix
        weights=[embedding_matrix],

        # Length of each padded input sequence
        input_length=max_len,

        # Freeze embeddings so GloVe vectors do NOT update during training
        trainable=False
    ),

    # Average all word embeddings into one fixed-length vector
    GlobalAveragePooling1D(),

    # Output layer for binary classification (0 or 1)
    Dense(1, activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
