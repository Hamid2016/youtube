# %% [markdown]
# #### ANN

# %% [markdown]
# #### Setup and dataset load

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Load manually from dataset_MNIST

# %%
import numpy as np

x_train_full = np.load('dataset_MNIST/train_images.npy')
y_train_full = np.load('dataset_MNIST/train_labels.npy')
x_test       = np.load('dataset_MNIST/test_images.npy')
y_test       = np.load('dataset_MNIST/test_labels.npy')

# %%
x_test.shape,x_train_full.shape
# Out:
# ((10000, 28, 28), (60000, 28, 28))

# %% [markdown]
# Train: 48,000 samples
#
# Validation: 12,000 samples
#
# Test: 10,000 samples

# %% [markdown]
# #### Normalize pixel values

# %%
x_train_full = x_train_full.astype("float32") / 255.0
x_test       = x_test.astype("float32") / 255.0

# %% [markdown]
# #### Create train/validation split

# %%
from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full,
    test_size=0.2, random_state=42, stratify=y_train_full
)

# %% [markdown]
# #### Build ANN model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout

model = Sequential([
    Flatten(input_shape=(28, 28)),   # Flatten 28x28 → 784
    Dense(128, activation='relu'),   # Hidden layer
    Dropout(0.2),                    # Regularization
    Dense(10, activation='softmax')  # Output layer (10 classes)
])
# Out:
# G:\DS\ML for teens\venv\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# #### Compile

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# #### Train for 5 epochs

# %%
history = model.fit(
    x_train, y_train,
    epochs=5,
    batch_size=128,
    validation_data=(x_val, y_val),
    verbose=1
)
# Out:
# Epoch 1/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8730 - loss: 0.4442 - val_accuracy: 0.9370 - val_loss: 0.2244
# Epoch 2/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9389 - loss: 0.2108 - val_accuracy: 0.9542 - val_loss: 0.1626
# Epoch 3/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9530 - loss: 0.1588 - val_accuracy: 0.9603 - val_loss: 0.1378
# Epoch 4/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9613 - loss: 0.1305 - val_accuracy: 0.9663 - val_loss: 0.1183
# Epoch 5/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9672 - loss: 0.1097 - val_accuracy: 0.9691 - val_loss: 0.1084

# %% [markdown]
# #### 375=48000/128

# %% [markdown]
# #### Evaluate on test set

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f} | Test loss: {test_loss:.4f}")
# Out:
# Test accuracy: 0.9703 | Test loss: 0.0997

# %% [markdown]
# #### Check overfitting

# %%
train_loss, train_acc = model.evaluate(x_train, y_train, verbose=0)
print(f"Train accuracy: {train_acc:.4f} | Train loss: {train_loss:.4f}")
# Out:
# Train accuracy: 0.9791 | Train loss: 0.0742

# %% [markdown]
# #### CNN

# %% [markdown]
# #### Load and prepare data

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Load Kaggle MNIST .npy files
x_train_full = np.load('./dataset_MNIST/train_images.npy')
y_train_full = np.load('./dataset_MNIST/train_labels.npy')
x_test       = np.load('./dataset_MNIST/test_images.npy')
y_test       = np.load('./dataset_MNIST/test_labels.npy')

# Normalize pixel values
x_train_full = x_train_full.astype('float32') / 255.0
x_test       = x_test.astype('float32') / 255.0

# Add channel dimension for CNN
x_train_full = np.expand_dims(x_train_full, -1)
x_test       = np.expand_dims(x_test, -1)

# Train/validation split
x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full,
    test_size=0.2, random_state=42, stratify=y_train_full
)

print('Train:', x_train.shape, y_train.shape)
print('Val  :', x_val.shape,   y_val.shape)
print('Test :', x_test.shape,  y_test.shape)
# Out:
# Train: (48000, 28, 28, 1) (48000,)
# Val  : (12000, 28, 28, 1) (12000,)
# Test : (10000, 28, 28, 1) (10000,)

# %% [markdown]
# #### Build CNN model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Dropout, Flatten

model = Sequential([
    # Convolution + Pooling
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    #the 32 means the number of filters (also called kernels or feature detectors) in that convolutional layer.
    #Each filter is a small 3×3 grid of weights that slides across the image.
    MaxPool2D((2, 2)),
    #(2, 2): This means the pooling window is 2×2 pixels.
    #Max pooling: From each 2×2 block of pixels, it keeps only the maximum value.


    # Flatten + Dense layers
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')  # 10 classes
])

model.summary()
# Out:
# G:\DS\ML for teens\venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_7 (Conv2D)                    │ (None, 26, 26, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 13, 13, 32)          │               0 │
# ...

# %% [markdown]
# #### Compile model

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',  # works with integer labels
    metrics=['accuracy']
)

# %% [markdown]
# #### Train model

# %%
history = model.fit(
    x_train, y_train,
    epochs=5,              # you can adjust
    batch_size=128,
    validation_data=(x_val, y_val),
    verbose=1
)
# Out:
# Epoch 1/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.8390 - loss: 0.5282 - val_accuracy: 0.9525 - val_loss: 0.1700
# Epoch 2/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.9268 - loss: 0.2501 - val_accuracy: 0.9675 - val_loss: 0.1078
# Epoch 3/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.9465 - loss: 0.1831 - val_accuracy: 0.9750 - val_loss: 0.0900
# Epoch 4/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.9544 - loss: 0.1544 - val_accuracy: 0.9775 - val_loss: 0.0770
# Epoch 5/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.9602 - loss: 0.1321 - val_accuracy: 0.9782 - val_loss: 0.0721

# %% [markdown]
# #### Evaluate performance

# %%
# Evaluate on training set
train_loss, train_acc = model.evaluate(x_train, y_train, verbose=0)
print(f"Train  | acc: {train_acc:.4f}  loss: {train_loss:.4f}")

# Validation metrics (last epoch from history)
val_acc  = history.history['val_accuracy'][-1]
val_loss = history.history['val_loss'][-1]
print(f"Val    | acc: {val_acc:.4f}  loss: {val_loss:.4f}")

# Evaluate on test set
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Test   | acc: {test_acc:.4f}  loss: {test_loss:.4f}")
# Out:
# Train  | acc: 0.9846  loss: 0.0500
# Val    | acc: 0.9782  loss: 0.0721
# Test   | acc: 0.9800  loss: 0.0627
