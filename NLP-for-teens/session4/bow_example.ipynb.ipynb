# %%
from sklearn.feature_extraction.text import CountVectorizer

texts = [
    "The food is good",
    "The service is good"
]

cv = CountVectorizer()
X = cv.fit_transform(texts)

print("Vocabulary:", cv.get_feature_names_out())
print("BoW matrix:\n", X.toarray())
# Out:
# Vocabulary: ['food' 'good' 'is' 'service' 'the']
# BoW matrix:
#  [[1 1 1 0 1]
#  [0 1 1 1 1]]
