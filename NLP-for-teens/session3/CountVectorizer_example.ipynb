# %%
from sklearn.feature_extraction.text import CountVectorizer

text = ["Alice likes apples", "Alice eats apples"]

cv = CountVectorizer()
bow_cv = cv.fit_transform(text)

print("Vocabulary:", cv.get_feature_names_out())
print("Counts:\n", bow_cv.toarray())
# Out:
# Vocabulary: ['alice' 'apples' 'eats' 'likes']
# Counts:
#  [[1 1 0 1]
#  [1 1 1 0]]
