# %% [markdown]
# #### read data

# %%
import pandas as pd

df = pd.read_csv("DataSet/noisy_df.csv")
df
# Out:
#      area  bedrooms  bathrooms  stories  parking  mainroad_yes  guestroom_yes  \
# 0    7420         4          2        3        2           1.0            0.0
# 1    8960         4          4        4        3           1.0            0.0
# 2    9960         3          2        2        2           1.0            0.0
# 3    7500         4          2        2        3           1.0            0.0
# 4    7420         4          1        2        2           1.0            1.0
# ..    ...       ...        ...      ...      ...           ...            ...
# 540  3000         2          1        1        2           1.0            0.0
# 541  2400         3          1        1        0           0.0            0.0
# 542  3620         2          1        1        0           1.0            0.0
# 543  2910         3          1        1        0           0.0            0.0
# 544  3850         3          1        2        0           1.0            0.0
#
#      basement_yes  hotwaterheating_yes  airconditioning_yes  ...  noise_91  \
# 0             0.0                  0.0                  1.0  ...  0.968645
# 1             0.0                  0.0                  1.0  ...  0.856399
# 2             1.0                  0.0                  0.0  ... -0.493001
# 3             1.0                  0.0                  1.0  ...  0.491919
# 4             1.0                  0.0                  1.0  ...  1.479944
# ..            ...                  ...                  ...  ...       ...
# 540           1.0                  0.0                  0.0  ... -0.328652
# 541           0.0                  0.0                  0.0  ... -0.676898
# 542           0.0                  0.0                  0.0  ... -0.244761
# 543           0.0                  0.0                  0.0  ... -0.330982
# 544           0.0                  0.0                  0.0  ...  0.316598
#
#      noise_92  noise_93  noise_94  noise_95  noise_96  noise_97  noise_98  \
# 0   -0.702053 -0.327662 -0.392108 -1.463515  0.296120  0.261055  0.005113
# 1    0.214094 -1.245739  0.173181  0.385317 -0.883857  0.153725  0.058209
# 2   -0.589365  0.849602  0.357015 -0.692910  0.899600  0.307300  0.812862
# 3   -1.320233  1.831459  1.179440 -0.469176 -1.713135  1.353872 -0.114540
# 4    0.077368 -0.861284  1.523124  0.538910 -1.037246 -0.190339 -0.875618
# ..        ...       ...       ...       ...       ...       ...       ...
# 540 -1.921180  0.316163 -0.213023 -0.175872  0.740002 -0.283755  2.806700
# 541  1.285149  0.909561  0.039832  0.223066  1.036306  0.661869  0.261482
# 542  0.073804 -0.643076  0.321994  1.827646 -0.166725 -0.681664  0.306680
# 543  0.809636  0.039601  1.533121 -0.150160  1.882975  2.062682  0.458044
# 544 -0.085493 -2.126328  0.459973 -0.616097 -1.376804  0.387000  0.320981
#
#      noise_99     price
# 0   -0.234587  13300000
# 1   -1.142970  12250000
# 2    0.629629  12250000
# 3    1.237816  12215000
# 4   -1.382800  11410000
# ..        ...       ...
# 540  0.808528   1820000
# 541 -0.450238   1767150
# 542 -0.795086   1750000
# 543  0.418275   1750000
# 544  0.981402   1750000
#
# [545 rows x 114 columns]

# %% [markdown]
# #### Separate features and target

# %%
X = df.drop(columns=["price"])
y = df["price"]

# %% [markdown]
# #### Standardize the Features

# %%
from sklearn.preprocessing import StandardScaler

# Standardize (zero mean, unit variance)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# #### Apply PCA

# %%
from sklearn.decomposition import PCA

# Fit PCA
# pca = PCA(0.6)

# or 
pca = PCA(n_components=20)

X_pca = pca.fit_transform(X_scaled)

# Explained variance
explained_var = pca.explained_variance_ratio_
X_pca.shape
# Out:
# (545, 46)

# %% [markdown]
# #### Cumulative variance

# %%
import numpy as np
cumulative_var = np.cumsum(explained_var)
cumulative_var
# Out:
# array([0.02482316, 0.04288773, 0.06038146, 0.07758561, 0.09456825,
#        0.11115831, 0.12763152, 0.14394893, 0.15958658, 0.17515646,
#        0.19046122, 0.20546371, 0.22014312, 0.23459793, 0.24884992,
#        0.26296064, 0.27697929, 0.29066035, 0.30401462, 0.31720831,
#        0.33037331, 0.34332732, 0.35598156, 0.36859473, 0.38098544,
#        0.39312047, 0.4052204 , 0.41724586, 0.42905106, 0.44067243,
#        0.45222834, 0.4635367 , 0.47470638, 0.48574607, 0.49660938,
#        0.50738688, 0.51800479, 0.52845631, 0.53874325, 0.54894496,
#        0.55897975, 0.56886216, 0.57865957, 0.58835805, 0.59794133,
#        0.60725111, 0.61650339, 0.62570397, 0.63477247, 0.64374162,
#        0.65264096, 0.6613282 , 0.66983359, 0.67821   , 0.68651107,
#        0.69472024, 0.70290052, 0.71098471, 0.71897736, 0.72682962,
#        0.73457722, 0.7422625 , 0.74984813, 0.75729   , 0.76462123,
#        0.77181065, 0.77886118, 0.78588198, 0.79272188, 0.79950736,
#        0.80617314])

# %% [markdown]
# #### Plot PCA variance

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(cumulative_var)+1), cumulative_var, marker='o')
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("PCA Variance Explained")
plt.grid(True)
plt.show()
